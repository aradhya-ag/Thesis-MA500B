# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('roll_rate_results.csv')

# %%
clean_quarters = df['quarter']
df['date'] = pd.PeriodIndex(clean_quarters, freq='Q').to_timestamp()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df['date'], df['mape'], color='#d62728', linewidth=2.5, marker='o', markersize=4)
ax.xaxis.set_major_locator(mdates.YearLocator(1)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.tick_params(axis='x', labelsize=12, rotation=0)

ax.set_ylabel('Forecasting Error (MAPE %)', fontsize=14)
ax.set_xlabel('Reporting Period', fontsize=14)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(loc='best', fontsize=12)


plt.tight_layout()
plt.show()
# Out:
# C:\Users\agraw\AppData\Local\Temp\ipykernel_18648\389396369.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='best', fontsize=12)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df['date'], df['mape'], color='#d62728', linewidth=2.5, marker='o', markersize=4)
ax.xaxis.set_major_locator(mdates.YearLocator(1)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.tick_params(axis='x', labelsize=12, rotation=0)


ax.axvspan(pd.to_datetime('2007-07-01'), pd.to_datetime('2009-06-30'), color='gray', alpha=0.3, label='2008 Financial Crisis')
ax.axvspan(pd.to_datetime('2017-04-01'), pd.to_datetime('2018-03-31'), color='orange', alpha=0.2, label='2017 US Hurricanes')
ax.axvspan(pd.to_datetime('2020-01-01'), pd.to_datetime('2020-10-30'), color='purple', alpha=0.2, label='COVID-19 Pandemic')

ax.set_ylabel('Forecasting Error (MAPE %)', fontsize=14)
ax.set_xlabel('Reporting Period', fontsize=14)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(loc='best', fontsize=12)


plt.tight_layout()
plt.savefig('arima_full_timeline.png', dpi=300)
plt.show()
